# %%
from pathlib import Path

import numba as nb
import numpy as np
import scipy.stats as stats

from natsort import natsorted

import matplotlib.pyplot as plt


plt.style.use("mike")
import warnings
warnings.simplefilter("ignore")


import astropy.units as u

import cmasher as cmr

green = "#33FF86"
purple = "#CE33FF"

# %matplotlib widget


from polarball.polarball import PolarResponse

# %%
r = PolarResponse.from_hdf5("/Users/jburgess/research/polar2/response/demo_rsp_database.h5")
# Out:
# [WARNING ] Maximum MC energy (794.67334) is smaller than maximum EBOUNDS energy (9933.33984375)

# %%
r.plot_verticies_ipv(selected_location=[10., 70.])
# Out:
# VBox(children=(Figure(camera=PerspectiveCamera(fov=45.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…
